# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
import numpy as np

# %%
df = pd.read_csv("data/data_preprocessed/processed_data.csv")
df.head()
# Out:
#   Country         Name  Year  Capacity  Economic  Ecosystems  Exposure  \
# 0     AFG  Afghanistan  1995  0.893281  0.496497    0.515884  0.480512
# 1     AFG  Afghanistan  1996  0.893892  0.496497    0.516995  0.480512
# 2     AFG  Afghanistan  1997  0.894459  0.496497    0.518030  0.480512
# 3     AFG  Afghanistan  1998  0.890161  0.496497    0.518156  0.480512
# 4     AFG  Afghanistan  1999  0.885896  0.496497    0.518156  0.480512
#
#        Food  Governance   Habitat    Health  Infrastructure  Readiness  \
# 0  0.665745    0.128090  0.602933  0.748302        0.355586   0.308182
# 1  0.665583    0.128090  0.604235  0.748302        0.354484   0.308181
# 2  0.665420    0.141392  0.605583  0.748302        0.353925   0.312614
# 3  0.657103    0.154694  0.606909  0.748302        0.353710   0.317047
# 4  0.648959    0.143689  0.608137  0.748302        0.352292   0.313378
#
#    Sensitivity    Social  Vulnerability     Water
# 0     0.419587  0.299958       0.612511  0.529692
# 1     0.419307  0.299954       0.612679  0.528281
# 2     0.419055  0.299952       0.612837  0.526853
# 3     0.418794  0.299949       0.611179  0.525424
# 4     0.419433  0.299947       0.609828  0.525585
