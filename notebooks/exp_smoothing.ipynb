# %%
import sys
sys.path.insert(0, "/home/zbezjak/code/donismous/Climate-Resilience")

from fetch_ndgain import fetch_ndgain
from preprocessing.pipeline import preprocess

# %%
raw_df = fetch_ndgain()
prepared_df = preprocess(raw_df)
raw_df.head()
# Out:
# Fetched 1000 / 194655 rows
# Fetched 2000 / 194655 rows
# Fetched 3000 / 194655 rows
# Fetched 4000 / 194655 rows
# Fetched 5000 / 194655 rows
# Fetched 6000 / 194655 rows
# Fetched 7000 / 194655 rows
# Fetched 8000 / 194655 rows
# Fetched 9000 / 194655 rows
# Fetched 10000 / 194655 rows
# Fetched 11000 / 194655 rows
# Fetched 12000 / 194655 rows
# Fetched 13000 / 194655 rows
# Fetched 14000 / 194655 rows
# Fetched 15000 / 194655 rows
# Fetched 16000 / 194655 rows
# Fetched 17000 / 194655 rows
# Fetched 18000 / 194655 rows
# Fetched 19000 / 194655 rows
# Fetched 20000 / 194655 rows
# Fetched 21000 / 194655 rows
# Fetched 22000 / 194655 rows
# Fetched 23000 / 194655 rows
# Fetched 24000 / 194655 rows
# Fetched 25000 / 194655 rows
# Fetched 26000 / 194655 rows
# Fetched 27000 / 194655 rows
# Fetched 28000 / 194655 rows
# Fetched 29000 / 194655 rows
# Fetched 30000 / 194655 rows
# Fetched 31000 / 194655 rows
# Fetched 32000 / 194655 rows
# Fetched 33000 / 194655 rows
# ...
